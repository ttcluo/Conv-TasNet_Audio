# %%
import os
print (os.getcwd())#获得当前目录
print (os.path.abspath('.'))#获得当前工作目录
# Out:
# /Users/larry/VsCodeProjects/Conv-TasNet_Audio
# /Users/larry/VsCodeProjects/Conv-TasNet_Audio

# %%
# !python train.py
# Out:
# 2023-12-13 09:52:05 [/Users/larry/VsCodeProjects/Conv-TasNet_Audio/./options/option.py:13 - INFO ] Reading .yml file .......
# 2023-12-13 09:52:05 [/Users/larry/VsCodeProjects/Conv-TasNet_Audio/./options/option.py:19 - INFO ] Export CUDA_VISIBLE_DEVICES = 0
# 2023-12-13 09:52:05 [/Users/larry/VsCodeProjects/Conv-TasNet_Audio/train.py:25 - INFO ] Building the model of Conv-TasNet
# 2023-12-13 09:52:05 [/Users/larry/VsCodeProjects/Conv-TasNet_Audio/train.py:28 - INFO ] Building the trainer of Conv-TasNet
# Traceback (most recent call last):
#   File "/Users/larry/VsCodeProjects/Conv-TasNet_Audio/train.py", line 43, in <module>
#     main()
#   File "/Users/larry/VsCodeProjects/Conv-TasNet_Audio/train.py", line 30, in main
#     trainer = Trainer(net, **opt['train'], resume=opt['resume'],
#   File "/Users/larry/VsCodeProjects/Conv-TasNet_Audio/trainer.py", line 65, in __init__
#     raise RuntimeError("CUDA device unavailable...exist")
# RuntimeError: CUDA device unavailable...exist

# %%
# !pip install soundfile
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !python Separation_wav.py
# Out:
# gpuid
# []
# 2023-12-13 11:05:36 [/Users/larry/VsCodeProjects/Conv-TasNet_Audio/./options/option.py:13 - INFO ] Reading .yml file .......
# 2023-12-13 11:05:36 [/Users/larry/VsCodeProjects/Conv-TasNet_Audio/./options/option.py:19 - INFO ] Export CUDA_VISIBLE_DEVICES = 0
# 2023-12-13 11:05:36 [/Users/larry/VsCodeProjects/Conv-TasNet_Audio/Separation_wav.py:29 - INFO ] Load checkpoint from best.pt, epoch  70
# torch.Size([44898])
# torch.Size([1, 44898])
# torch.Size([1, 44898])
# torch.Size([1, 512, 5611])
# torch.Size([1, 512, 5611])
# torch.Size([1, 512, 5611])
# torch.Size([1, 512, 5611])
# torch.Size([1, 512, 5611])
# torch.Size([1, 128, 5611])
# torch.Size([1, 128, 5611])
# torch.Size([1, 128, 5611])
# torch.Size([1, 128, 5611])
# torch.Size([1, 128, 5611])
# torch.Size([1, 512, 5611])
# torch.Size([1, 512, 5611])
# torch.Size([1, 512, 5611])
# torch.Size([1, 512, 5611])
# torch.Size([1, 512, 5611])
# torch.Size([1, 1, 1])
# torch.Size([1, 1, 1])
# torch.Size([1, 512, 5611])
# ...
